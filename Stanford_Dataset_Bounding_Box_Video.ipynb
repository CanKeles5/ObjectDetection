# %% [markdown]
# <a href="https://colab.research.google.com/github/CanKeles5/ObjectDetection/blob/main/Stanford_Dataset_Bounding_Box_Video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
vidcap = cv2.VideoCapture('/content/drive/MyDrive/data-yolov5/videos/quad/video0/video.mov')
success,image = vidcap.read()
count = 0
while success:
  cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
annot = open("/content/drive/MyDrive/data-yolov5/annotations/quad/video0/annotations.txt","r")

# %%
# Python program to 
# demonstrate readline() 

# Using readline()
count = 0
  
while True: 
    count += 1
  
    # Get next line from file 
    line = annot.readline() 
    # if line is empty 
    # end of file is reached 
    if not line: 
        break

    _, x_min, y_min, x_max, y_max, frameNo, lost, _, _, _ = line.split()
    x_min = int(x_min)
    y_min = int(y_min)
    x_max = int(x_max)
    y_max = int(y_max)
    frameNo = int(frameNo)
    lost = int(lost)

    if lost==0:
      currImg = cv2.imread("/content/frame" + str(frameNo) + ".jpg")
      currImg = cv2.rectangle(currImg, (x_min, y_min), (x_max, y_max), color, 2)
      cv2.imwrite("/content/frame" + str(frameNo) + ".jpg", currImg) 

    #print("Line{}: {}".format(count, line.strip()))

# %%
annot.close()

# %%
import os

image_folder = '/content'
video_name = '001video.avi'

images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]

frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 30, (width,height))

#for image in images:
#    video.write(cv2.imread(os.path.join(image_folder, image)))

for i in range(509):
  img = cv2.imread("/content/frame" + str(i) + ".jpg")
  video.write(img)

cv2.destroyAllWindows()
video.release()

# %%
from subprocess import call

# %%
out_root = '/content/001video.avi'
dir = out_root.strip(".avi")
command = "ffmpeg -i %s.avi %s.mp4" % (dir, dir) #Use ffmped to compress avi to mp4, note the two paths
call(command.split())
# Out:
# 0

# %%
#image = cv2.imread('the path to your image')
#cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,255,0),2) # add rectangle to image
